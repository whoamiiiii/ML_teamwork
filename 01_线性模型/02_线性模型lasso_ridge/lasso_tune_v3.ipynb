# %% [markdown]
# # 线性模型 Lasso — Alpha 调参版（baseline 对齐口径，含截距）
#
# 本 notebook 在 OLS baseline 的流程上替换为 Lasso，并在训练集内部验证集选择 alpha。预测口径沿用原 baseline：train/test 均逐日拟合 beta，拼接后 EWM，再 shift(1)。

# %% [markdown]
# ## Step 0 — 参数配置
#
# | 参数 | 默认值 | 用途 |
# |------|--------|------|
# | `FOLD_DIR` | `00_fold切分/.../output/20260526` | fold CSV 目录 |
# | `FOLD_ID` | `1` | 当前 fold 编号 |
# | `LABEL_COL` | `FWD_RET_10D` | 标签列名 |
# | `WINSORIZE_MAD` | `3.0` | MAD 倍数 |
# | `IC_THRESHOLD` | `0.02` | IC 初筛阈值 |
# | `T_STAT_THRESHOLD` | `2.0` | t 统计量阈值 |
# | `CORR_THRESHOLD` | `0.7` | 共线性阈值 |
# | `EWM_HALFLIFE` | `20` | β 平滑半衰期 |
# | `MODEL_TYPE` | `lasso` | 模型类型：`lasso` 或 `ridge` |
# | `ALPHA` | `0.001` | 正则化强度，越大惩罚越重 |

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from scipy.stats import spearmanr
from sklearn.linear_model import Lasso, Ridge
from typing import List, Dict, Tuple, Optional
import datetime as _dt
import warnings
warnings.filterwarnings("ignore")

# ===== 参数区 =====
FOLD_DIR         = Path(r"D:/个人/量化/ML_teamwork/0_fold切分/01_train&test/output/20260526")
FOLD_ID          = 1
LABEL_COL        = "FWD_RET_10D"
WINSORIZE_MAD    = 3.0
IC_THRESHOLD     = 0.02
T_STAT_THRESHOLD = 2.0
CORR_THRESHOLD   = 0.7
EWM_HALFLIFE     = 20
OUTPUT_DIR       = Path(r"D:/个人/量化/ML_teamwork/01_线性模型/02_线性模型lasso_ridge/output")

# ===== Lasso / Ridge 参数 =====
MODEL_TYPE = "lasso"   # 本 notebook 为 Lasso 调参版；如需 Ridge，可改为 "ridge"
ALPHA_GRID = [0.0001, 0.001, 0.01, 0.1]   # 候选 alpha，将在 Step 5.5 中用训练集内部验证集选择
ALPHA = None                              # 最优 alpha 会在 Step 5.5 后写入
VAL_DAYS = 60                             # 从训练集末尾拿 60 天做验证集

# 截距列名。sklearn 的 intercept_ 不受 Lasso/Ridge 惩罚；
# 保存进 beta_history 后，预测时使用 intercept + X @ beta。
INTERCEPT_COL = "__intercept__"

print("参数配置完成")
print(f"  Fold 目录: {FOLD_DIR}")
print(f"  Fold ID: {FOLD_ID}")
print(f"  标签列: {LABEL_COL}")
print(f"  Winsorize MAD: {WINSORIZE_MAD}")
print(f"  IC 阈值: {IC_THRESHOLD}  t 阈值: {T_STAT_THRESHOLD}")
print(f"  共线性阈值: {CORR_THRESHOLD}")
print(f"  EWM halflife: {EWM_HALFLIFE}")
print(f"  模型类型: {MODEL_TYPE.upper()}")
print(f"  Alpha 候选网格: {ALPHA_GRID}  (最优值将在 Step 5.5 中确定)")
# Out:
# 参数配置完成
#   Fold 目录: D:\个人\量化\ML_teamwork\0_fold切分\01_train&test\output\20260526
#   Fold ID: 1
#   标签列: FWD_RET_10D
#   Winsorize MAD: 3.0
#   IC 阈值: 0.02  t 阈值: 2.0
#   共线性阈值: 0.7
#   EWM halflife: 20
#   模型类型: LASSO
#   Alpha 候选网格: [0.0001, 0.001, 0.01, 0.1]  (最优值将在 Step 5.5 中确定)

# %% [markdown]
# ## Step 1 — 函数定义
#
# 共 15 个函数，在 baseline 基础上新增 `daily_regularized_beta`，其余 14 个与 baseline 完全一致。
#
# | 函数 | 用途 | 变化 |
# |------|------|------|
# | `load_fold` | 加载 fold CSV | 不变 |
# | `identify_columns` | 识别特征列和标签列 | 不变 |
# | `cross_section_winsorize` | 逐日截面 MAD 去极值 | 不变 |
# | `cross_section_demean` | 逐日截面 demean | 不变 |
# | `cross_section_zscore` | 逐日截面 z-score | 不变 |
# | `compute_ic_panel` | 逐日 Spearman IC 面板 | 不变 |
# | `summarize_ic` | IC 汇总统计 | 不变 |
# | `filter_by_ic` | 阈值过滤因子 | 不变 |
# | `spearman_union_find` | Spearman 相关矩阵 + 并查集 | 不变 |
# | `select_representatives` | 每组取 \|IC\| 最大代表 | 不变 |
# | **`daily_regularized_beta`** | **逐日 Lasso/Ridge 拟合** | **新增** |
# | `smooth_beta_ewm` | β 时间序列 EWM 平滑 | 不变 |
# | `predict_walkforward` | Walk-forward 预测 | 不变 |
# | `evaluate_ic` | 日度 IC + 汇总评估 | 不变 |

# %%
# ===== 数据加载 & 列识别（与 baseline 完全相同）=====

def load_fold(fold_dir: Path, fold_id: int) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """加载指定 fold 的训练/测试 CSV。

    输入:
        fold_dir: CSV 文件所在目录 (Path)
        fold_id: fold 编号 (int)

    输出:
        (train_df, test_df): 均已按 trade_date + ts_code 排序
    """
    tr = pd.read_csv(fold_dir / f"fold_{fold_id}_train.csv", parse_dates=["trade_date"])
    te = pd.read_csv(fold_dir / f"fold_{fold_id}_test.csv", parse_dates=["trade_date"])
    tr.sort_values(["trade_date", "ts_code"], inplace=True)
    tr.reset_index(drop=True, inplace=True)
    te.sort_values(["trade_date", "ts_code"], inplace=True)
    te.reset_index(drop=True, inplace=True)
    return tr, te

def identify_columns(df: pd.DataFrame) -> Tuple[List[str], str]:
    """识别特征列和标签列。

    输入:
        df: 因子表 DataFrame

    输出:
        (feature_cols, label_col): ALPHA_* 列名列表, 标签列名
    """
    feat = [c for c in df.columns if c.startswith("ALPHA_")]
    labels = [c for c in df.columns if c.startswith("FWD_RET_")]
    assert len(labels) >= 1, f"未找到 FWD_RET_* 标签列, cols={df.columns.tolist()}"
    label = labels[0]
    assert all(not c.startswith("FWD_RET_") for c in feat), "特征列含未来收益字段!"
    return feat, label


print("[OK] 数据函数定义完成")
# Out:
# [OK] 数据函数定义完成

# %%
# ===== 截面预处理=====

def cross_section_winsorize(df: pd.DataFrame, cols: List[str], n_mad: float = 3.0) -> pd.DataFrame:
    """逐日截面 MAD 去极值。

    输入:
        df: 含 trade_date 的 panel
        cols: 因子列名列表
        n_mad: MAD 倍数

    输出:
        同形 DataFrame, 列被截断到 [median - n*MAD, median + n*MAD]

    注：逻辑与 baseline 完全一致。改用 numpy 布尔掩码原地处理，
        避免 pandas loc/groupby.apply 触发全量 reindex 导致 OOM。
        数值结果与 baseline 无差异。
    """
    arr   = df[cols].to_numpy(dtype=float, copy=True)
    dates = df["trade_date"].to_numpy()
    for d in np.unique(dates):
        mask = dates == d
        sub  = arr[mask]
        med  = np.nanmedian(sub, axis=0)
        mad  = np.nanmedian(np.abs(sub - med), axis=0) * 1.4826
        arr[mask] = np.clip(sub, med - n_mad * mad, med + n_mad * mad)
    df = df.copy()
    df[cols] = arr
    return df


def cross_section_demean(df: pd.DataFrame, cols: List[str]) -> pd.DataFrame:
    """逐日截面 demean。

    输入:
        df: 含 trade_date 的 panel
        cols: 因子列名列表

    输出:
        同形 DataFrame, 每列减去当日截面均值

    注：逻辑与 baseline 完全一致。改用 numpy 布尔掩码原地处理。
        数值结果与 baseline 无差异。
    """
    arr   = df[cols].to_numpy(dtype=float, copy=True)
    dates = df["trade_date"].to_numpy()
    for d in np.unique(dates):
        mask      = dates == d
        arr[mask] = arr[mask] - np.nanmean(arr[mask], axis=0)
    df = df.copy()
    df[cols] = arr
    return df


def cross_section_zscore(df: pd.DataFrame, cols: List[str]) -> pd.DataFrame:
    """逐日截面 z-score 标准化。

    输入:
        df: 含 trade_date 的 panel
        cols: 因子列名列表

    输出:
        同形 DataFrame, 每列 (x - mean) / std

    注：逻辑与 baseline 完全一致。改用 numpy 布尔掩码原地处理。
        数值结果与 baseline 无差异。
    """
    arr   = df[cols].to_numpy(dtype=float, copy=True)
    dates = df["trade_date"].to_numpy()
    for d in np.unique(dates):
        mask = dates == d
        sub  = arr[mask]
        mu   = np.nanmean(sub, axis=0)
        sd   = np.nanstd(sub, axis=0, ddof=0)
        sd[sd == 0] = 1
        arr[mask] = (sub - mu) / sd
    df = df.copy()
    df[cols] = arr
    return df

# %%
# ===== IC 筛选 & 共线去重（与 baseline 完全相同）=====

def compute_ic_panel(df: pd.DataFrame, feat_cols: List[str], label_col: str) -> pd.DataFrame:
    """逐日截面 Spearman IC 面板。

    输入:
        df: 含 trade_date 的 panel
        feat_cols: 特征列名列表
        label_col: 标签列名

    输出:
        DataFrame index=trade_date, columns=feat_cols, 值为日度 Spearman IC
    """
    out = {}
    for d, g in df.groupby("trade_date"):
        out[d] = g[feat_cols].corrwith(g[label_col], method="spearman")
    return pd.DataFrame(out).T.sort_index()


def summarize_ic(ic_panel: pd.DataFrame) -> pd.DataFrame:
    """IC 面板汇总统计。

    输入:
        ic_panel: compute_ic_panel 输出, index=date, columns=feat

    输出:
        DataFrame index=feat, columns=[ic_mean, ic_std, t_stat, pos_ratio]
    """
    mu = ic_panel.mean()
    sd = ic_panel.std()
    n = ic_panel.notna().sum()
    t = mu / sd * np.sqrt(n)
    pos = (ic_panel > 0).mean()
    return pd.DataFrame({"ic_mean": mu, "ic_std": sd, "t_stat": t, "pos_ratio": pos})


def filter_by_ic(ic_summary: pd.DataFrame, ic_th: float = 0.02, t_th: float = 2.0) -> List[str]:
    """按 |IC| 和 |t| 阈值过滤因子。

    输入:
        ic_summary: summarize_ic 输出
        ic_th: |IC mean| 下限
        t_th: |t_stat| 下限

    输出:
        通过筛选的因子名列表
    """
    mask = (ic_summary["ic_mean"].abs() > ic_th) & (ic_summary["t_stat"].abs() > t_th)
    return ic_summary.index[mask].tolist()


def spearman_union_find(df: pd.DataFrame, cols: List[str], corr_th: float = 0.7) -> List[List[str]]:
    """Spearman 相关矩阵 + 并查集分组, 将 |ρ| > corr_th 的因子聚为一组。

    输入:
        df: train DataFrame
        cols: 候选因子列名
        corr_th: 相关系数阈值

    输出:
        list[list[str]], 每个子表是一组共线因子
    """
    corr = df[cols].corr(method="spearman").abs().values
    np.fill_diagonal(corr, 0)
    n = len(cols)
    parent = list(range(n))

    def find(x):
        while parent[x] != x:
            parent[x] = parent[parent[x]]
            x = parent[x]
        return x

    def union(a, b):
        ra, rb = find(a), find(b)
        if ra != rb:
            parent[ra] = rb

    rows, ccols = np.where(corr > corr_th)
    for a, b in zip(rows, ccols):
        if a < b:
            union(a, b)

    groups = {}
    for i, c in enumerate(cols):
        groups.setdefault(find(i), []).append(c)
    return list(groups.values())


def select_representatives(groups: List[List[str]], ic_summary: pd.DataFrame) -> List[str]:
    """每组共线因子中选 |IC mean| 最大的作为代表。

    输入:
        groups: spearman_union_find 输出
        ic_summary: summarize_ic 输出

    输出:
        代表因子名列表
    """
    reps = []
    for grp in groups:
        if len(grp) == 1:
            reps.append(grp[0])
        else:
            best = ic_summary.loc[grp, "ic_mean"].abs().idxmax()
            reps.append(best)
    return reps


print("[OK] IC 筛选 & 共线去重函数定义完成")
# Out:
# [OK] IC 筛选 & 共线去重函数定义完成

# %%
# ===== 建模核心：daily_regularized_beta（替换 daily_ols_beta）=====

def daily_regularized_beta(
    df: pd.DataFrame,
    x_cols: List[str],
    y_col: str,
    model_type: str = "lasso",
    alpha: float = 0.001
) -> pd.DataFrame:
    """逐日截面 Lasso / Ridge 拟合，返回 beta 时间序列。

    输入:
        df: 含 trade_date 的 panel 数据
        x_cols: 特征列名
        y_col: 标签列名，例如 FWD_RET_10D
        model_type: "lasso" 或 "ridge"
        alpha: 正则化强度

    输出:
        DataFrame
        - index: trade_date
        - columns: [INTERCEPT_COL] + x_cols
        - 每一行是一日截面模型的截距和因子系数

    说明:
        sklearn 中 fit_intercept=True 时，intercept_ 不参与 Lasso/Ridge 正则化惩罚。
        预测时应使用: y_pred = intercept + X @ beta。
    """
    assert model_type in ("lasso", "ridge"), f"model_type 必须是 lasso 或 ridge，当前: {model_type}"

    rows = []

    for d, g in df.groupby("trade_date"):
        X = g[x_cols].to_numpy(dtype=float)
        y = g[y_col].to_numpy(dtype=float)

        # 过滤含 NaN/Inf 的行
        mask = np.isfinite(X).all(axis=1) & np.isfinite(y)
        if mask.sum() < len(x_cols) + 5:
            continue

        if model_type == "lasso":
            model = Lasso(alpha=alpha, fit_intercept=True, max_iter=10000)
        else:
            model = Ridge(alpha=alpha, fit_intercept=True)

        model.fit(X[mask], y[mask])

        coef_with_intercept = np.r_[float(model.intercept_), model.coef_.astype(float)]
        rows.append((d, coef_with_intercept))

    if not rows:
        return pd.DataFrame(columns=[INTERCEPT_COL] + x_cols)

    idx = [r[0] for r in rows]
    arr = np.vstack([r[1] for r in rows])
    return pd.DataFrame(arr, index=idx, columns=[INTERCEPT_COL] + x_cols)


print("[OK] daily_regularized_beta 定义完成（含截距）")
# Out:
# [OK] daily_regularized_beta 定义完成（含截距）

# %%
# ===== EWM 平滑 / Walk-Forward 预测 / IC 评估 =====

def smooth_beta_ewm(beta_df: pd.DataFrame, halflife: int = 20) -> pd.DataFrame:
    """beta 时间序列 EWM 平滑。

    输入:
        beta_df: daily_regularized_beta 输出，index=date
        halflife: EWM 半衰期（交易日）

    输出:
        同形 DataFrame，每列 EWM 平滑
    """
    return beta_df.sort_index().ewm(halflife=halflife, adjust=False).mean()


def predict_walkforward(
    test_df: pd.DataFrame,
    x_cols: List[str],
    beta_ewm_shifted: pd.DataFrame,
    label_col: str
) -> pd.DataFrame:
    """测试日 t 用 beta_ewm[t-1] 预测。

    输入:
        test_df: 测试集 panel
        x_cols: 特征列名
        beta_ewm_shifted: smooth_beta_ewm 输出再 shift(1)，index=date
        label_col: 真实收益列名

    输出:
        DataFrame columns=[trade_date, ts_code, y_pred, y_true]

    说明:
        若 beta 中包含 INTERCEPT_COL，则预测公式为:
        y_pred = intercept + X @ beta
        截距对每日横截面排序和日度 IC 基本不产生影响，但能让预测值本身更完整。
    """
    records = []

    for d, g in test_df.groupby("trade_date"):
        if d not in beta_ewm_shifted.index:
            continue

        beta_row = beta_ewm_shifted.loc[d]
        if not np.isfinite(beta_row.to_numpy(dtype=float)).all():
            continue

        intercept = float(beta_row[INTERCEPT_COL]) if INTERCEPT_COL in beta_row.index else 0.0
        b = beta_row[x_cols].to_numpy(dtype=float)

        X = g[x_cols].to_numpy(dtype=float)
        y_true = g[label_col].to_numpy(dtype=float)
        valid = np.isfinite(X).all(axis=1) & np.isfinite(y_true)

        if valid.sum() == 0:
            continue

        g_valid = g.loc[valid]
        y_pred = intercept + X[valid] @ b

        tmp = pd.DataFrame({
            "trade_date": d,
            "ts_code": g_valid["ts_code"].values,
            "y_pred": y_pred,
            "y_true": y_true[valid]
        })
        records.append(tmp)

    if not records:
        return pd.DataFrame(columns=["trade_date", "ts_code", "y_pred", "y_true"])

    return pd.concat(records, ignore_index=True)


def evaluate_ic(pred_df: pd.DataFrame) -> Tuple[pd.Series, dict]:
    """日度 IC + 汇总评估。

    输入:
        pred_df: predict_walkforward 输出

    输出:
        (ic_series, summary_dict)
        ic_series: index=trade_date, 值=日度 Spearman IC
        summary_dict: ic_mean / ic_std / ic_ir / pos_ratio / n_days
    """
    if pred_df is None or pred_df.empty:
        return pd.Series(dtype=float), {}

    df = pred_df.replace([np.inf, -np.inf], np.nan).dropna(subset=["y_pred", "y_true"])

    ic_list = []
    for d, g in df.groupby("trade_date"):
        if len(g) < 5:
            continue
        ic, _ = spearmanr(g["y_pred"], g["y_true"])
        if np.isfinite(ic):
            ic_list.append((d, ic))

    if not ic_list:
        return pd.Series(dtype=float), {}

    ic_series = pd.Series(dict(ic_list)).sort_index()
    n = len(ic_series)
    mu, sd = ic_series.mean(), ic_series.std()

    # IC IR 年化：一年约 252/10 = 25.2 个调仓周期
    ic_ir = (mu / sd) * np.sqrt(252 / 10) if sd > 0 else np.nan

    summary = {
        "ic_mean": mu,
        "ic_std": sd,
        "ic_ir": ic_ir,
        "pos_ratio": (ic_series > 0).mean(),
        "n_days": n
    }
    return ic_series, summary


print("[OK] Step 1 全部函数定义完成")
# Out:
# [OK] Step 1 全部函数定义完成

# %% [markdown]
# ## Step 2 — 数据加载
#
# 读取 fold CSV，检查行列数。与 baseline 完全相同。

# %%
train_df, test_df = load_fold(FOLD_DIR, FOLD_ID)
feature_cols, label_col = identify_columns(train_df)

print(f"训练集: {train_df.shape[0]:,} 行, {train_df['trade_date'].nunique()} 日")
print(f"  日期范围: {train_df['trade_date'].min().date()} ~ {train_df['trade_date'].max().date()}")
print(f"测试集:  {test_df.shape[0]:,} 行, {test_df['trade_date'].nunique()} 日")
print(f"  日期范围: {test_df['trade_date'].min().date()} ~ {test_df['trade_date'].max().date()}")
print(f"因子列数: {len(feature_cols)}")
print(f"标签列: {label_col}")
print(f"训练集标签缺失率: {train_df[label_col].isna().mean():.2%}")
print(f"测试集标签缺失率:  {test_df[label_col].isna().mean():.2%}")
# Out:
# 训练集: 282,719 行, 976 日
#   日期范围: 2015-12-31 ~ 2019-12-31
# 测试集:  32,331 行, 108 日
#   日期范围: 2020-01-16 ~ 2020-07-01
# 因子列数: 230
# 标签列: FWD_RET_10D
# 训练集标签缺失率: 0.00%
# 测试集标签缺失率:  0.00%

# %% [markdown]
# ## Step 3 — 截面预处理
#
# train 和 test **各自独立**处理，防止数据泄漏。三步流水线：MAD Winsorize → Demean → Z-score。
#
# 与 baseline 完全相同，包括缺失值策略（不填充，NaN 自然传播）。

# %%
print("3a. MAD Winsorize...")
train_df = cross_section_winsorize(train_df, feature_cols, WINSORIZE_MAD)
test_df  = cross_section_winsorize(test_df,  feature_cols, WINSORIZE_MAD)

print("3b. Demean...")
train_df = cross_section_demean(train_df, feature_cols)
test_df  = cross_section_demean(test_df,  feature_cols)

print("3c. Z-score...")
train_df = cross_section_zscore(train_df, feature_cols)
test_df  = cross_section_zscore(test_df,  feature_cols)

print("[OK] 截面预处理完成")
# Out:
# 3a. MAD Winsorize...
# 3b. Demean...
# 3c. Z-score...
# [OK] 截面预处理完成

# %% [markdown]
# ## Step 4 — IC 初筛
#
# **只用训练集**计算 Spearman IC，过滤 `|ic_mean| > 0.02` 且 `|t_stat| > 2.0` 的因子。
#
# 与 baseline 完全相同（IC 筛选与模型类型无关）。

# %%
print("计算训练集 IC 面板（可能需要几分钟）...")
ic_panel  = compute_ic_panel(train_df, feature_cols, label_col)
ic_summary = summarize_ic(ic_panel)
kept_ic   = filter_by_ic(ic_summary, IC_THRESHOLD, T_STAT_THRESHOLD)

print(f"[OK] IC 初筛: {len(feature_cols)} → {len(kept_ic)} 个因子")
print(f"  IC 均值范围: [{ic_summary.loc[kept_ic,'ic_mean'].min():.4f}, {ic_summary.loc[kept_ic,'ic_mean'].max():.4f}]")
print(f"  t 统计量范围: [{ic_summary.loc[kept_ic,'t_stat'].abs().min():.2f}, {ic_summary.loc[kept_ic,'t_stat'].abs().max():.2f}]")
# Out:
# 计算训练集 IC 面板（可能需要几分钟）...
# [OK] IC 初筛: 230 → 76 个因子
#   IC 均值范围: [-0.0506, 0.0571]
#   t 统计量范围: [2.77, 13.51]

# %% [markdown]
# ## Step 5 — 共线性去重
#
# Spearman 相关矩阵 + 并查集，`|ρ| > 0.7` 的因子聚为一组，每组保留 IC 最大的代表。
#
# 与 baseline 完全相同。

# %%
print("共线性分组...")
groups     = spearman_union_find(train_df, kept_ic, CORR_THRESHOLD)
kept_final = select_representatives(groups, ic_summary)

print(f"[OK] 共线去重: {len(kept_ic)} → {len(kept_final)} 个因子")
group_sizes = sorted([len(g) for g in groups], reverse=True)
print(f"  最大共线组大小: {group_sizes[0]}")
print(f"  保留因子（前10）: {kept_final[:10]}")
# Out:
# 共线性分组...
# [OK] 共线去重: 76 → 38 个因子
#   最大共线组大小: 13
#   保留因子（前10）: ['ALPHA_1', 'ALPHA_182', 'ALPHA_4', 'ALPHA_12', 'ALPHA_13', 'ALPHA_94', 'ALPHA_26', 'ALPHA_29', 'ALPHA_69', 'ALPHA_34']

# %%
# ===== Step 5.5 — Alpha 网格搜索（只在训练集内部进行）=====

x_cols = kept_final

if len(x_cols) == 0:
    raise ValueError("共线去重后没有保留任何因子，请检查 IC_THRESHOLD / T_STAT_THRESHOLD / CORR_THRESHOLD")

# 从训练集末尾切出验证集，剩余部分做搜索训练集
all_dates = sorted(train_df["trade_date"].unique())
if len(all_dates) <= VAL_DAYS + 5:
    raise ValueError(f"训练集交易日过少，无法切出 VAL_DAYS={VAL_DAYS} 的验证集")

val_dates = all_dates[-VAL_DAYS:]
search_dates = all_dates[:-VAL_DAYS]

search_df = train_df[train_df["trade_date"].isin(search_dates)].copy()
val_df = train_df[train_df["trade_date"].isin(val_dates)].copy()

print(f"搜索训练集: {len(search_dates)} 天；验证集: {len(val_dates)} 天")
print(f"  搜索集日期范围: {search_dates[0]} ~ {search_dates[-1]}")
print(f"  验证集日期范围: {val_dates[0]} ~ {val_dates[-1]}")
print(f"  候选 alpha: {ALPHA_GRID}")

best_alpha = None
best_ic = -np.inf

for a in ALPHA_GRID:
    beta_search = daily_regularized_beta(search_df, x_cols, label_col, MODEL_TYPE, a)
    beta_search_ewm = smooth_beta_ewm(beta_search, EWM_HALFLIFE)

    # 关键修正：
    # beta_search_ewm 的 index 只有搜索训练集日期，不包含验证集日期。
    # 因此先把验证集日期并入 index，再 ffill，让验证期可使用搜索训练期最后可用 beta。
    combined_idx = pd.Index(beta_search_ewm.index).union(pd.Index(val_dates)).sort_values()
    beta_extended = beta_search_ewm.reindex(combined_idx).ffill()
    beta_shifted = beta_extended.shift(1)

    pred_val = predict_walkforward(val_df, x_cols, beta_shifted, label_col)

    _, val_summary = evaluate_ic(pred_val)
    ic = val_summary.get("ic_mean", -np.inf)

    print(f"  alpha={a:.6f}  beta行数={len(beta_search):4d}  pred_val行数={len(pred_val):6d}  val IC={ic:.6f}")

    if np.isfinite(ic) and ic > best_ic:
        best_ic = ic
        best_alpha = a

if best_alpha is None:
    best_alpha = ALPHA_GRID[0]
    print(f"\n[WARN] 所有 alpha 验证集 IC 无效，回退到默认 alpha={best_alpha}")
else:
    print(f"\n[OK] 最优 alpha={best_alpha}，验证集 IC={best_ic:.6f}")

ALPHA = best_alpha
print(f"ALPHA 已更新为: {ALPHA}")
# Out:
# 搜索训练集: 916 天；验证集: 60 天
#   搜索集日期范围: 2015-12-31 00:00:00 ~ 2019-10-08 00:00:00
#   验证集日期范围: 2019-10-09 00:00:00 ~ 2019-12-31 00:00:00
#   候选 alpha: [0.0001, 0.001, 0.01, 0.1]
#   alpha=0.000100  beta行数= 916  pred_val行数= 10435  val IC=0.005350
#   alpha=0.001000  beta行数= 916  pred_val行数= 10435  val IC=-0.003580
#   alpha=0.010000  beta行数= 916  pred_val行数= 10435  val IC=-0.027277
#   alpha=0.100000  beta行数= 916  pred_val行数= 10435  val IC=-inf
#
# [OK] 最优 alpha=0.0001，验证集 IC=0.005350
# ALPHA 已更新为: 0.0001

# %% [markdown]
# ## Step 6 — 逐日正则化回归
#
# **核心改动**：用 `daily_regularized_beta` 替换 baseline 的 `daily_ols_beta`。
#
# - `MODEL_TYPE = "lasso"` 时：L1 惩罚，部分系数被压缩至 0
# - `MODEL_TYPE = "ridge"` 时：L2 惩罚，所有系数变小但保持非零
#
# 输出格式与 baseline 完全一致，后续步骤无需改动。

# %%
# ===== Step 6 — 逐日正则化回归 =====

# x_cols 已在 Step 5.5 中定义为 kept_final。这里再次赋值，保证单独运行本 cell 时变量清晰。
x_cols = kept_final

print(f"训练集逐日 {MODEL_TYPE.upper()} 拟合（alpha={ALPHA}）...")
beta_train = daily_regularized_beta(train_df, x_cols, label_col, MODEL_TYPE, ALPHA)
print(f"  训练集 beta: {beta_train.shape}")

print(f"测试集逐日 {MODEL_TYPE.upper()} 拟合（baseline 对齐口径）...")
beta_test = daily_regularized_beta(test_df, x_cols, label_col, MODEL_TYPE, ALPHA)
print(f"  测试集 beta: {beta_test.shape}")

# Lasso 稀疏性统计：只统计因子系数，不统计截距
if MODEL_TYPE == "lasso":
    coef_cols = [c for c in beta_train.columns if c != INTERCEPT_COL]
    nonzero_ratio = (beta_train[coef_cols].abs() > 1e-8).mean().mean()
    print(f"  Lasso 非零系数比例（训练集均值，不含截距）: {nonzero_ratio:.2%}")

print(f"[OK] Step 6 完成")
# Out:
# 训练集逐日 LASSO 拟合（alpha=0.0001）...
#   训练集 beta: (976, 39)
# 测试集逐日 LASSO 拟合（baseline 对齐口径）...
#   测试集 beta: (108, 39)
#   Lasso 非零系数比例（训练集均值，不含截距）: 88.03%
# [OK] Step 6 完成

# %% [markdown]
# ## Step 7 — EWM 平滑 + Shift（与 baseline 完全相同）
#
# `shift(1)` 是防泄漏核心：确保 t 日预测只用 t-1 日及之前的信息。

# %%
# ===== Step 7 — EWM 平滑 + shift(1) =====
# 为了与原 OLS baseline 保持一致，这里沿用 baseline 对齐口径：
# train/test 均逐日拟合 beta，拼接后做 EWM，再 shift(1)。
# 该口径便于横向比较 OLS / Lasso / Ridge，但不是最严格样本外口径。

beta_all = pd.concat([beta_train, beta_test]).sort_index()
beta_ewm = smooth_beta_ewm(beta_all, EWM_HALFLIFE)
beta_for_pred = beta_ewm.shift(1)   # t 日使用 t-1 日及之前的信息

print(f"beta_train:    {beta_train.shape}")
print(f"beta_test:     {beta_test.shape}")
print(f"beta_all:      {beta_all.shape}")
print(f"beta_ewm:      {beta_ewm.shape}")
print(f"beta_for_pred: {beta_for_pred.shape}")
print(f"[OK] Step 7 完成（baseline 对齐口径：EWM + shift(1)）")
# Out:
# beta_train:    (976, 39)
# beta_test:     (108, 39)
# beta_all:      (1084, 39)
# beta_ewm:      (1084, 39)
# beta_for_pred: (1084, 39)
# [OK] Step 7 完成（baseline 对齐口径：EWM + shift(1)）

# %% [markdown]
# ## Step 8 — Walk-Forward 预测（与 baseline 完全相同）
#
# 对测试集每天，用 `β_ewm[t-1]` 对当天所有股票打分。

# %%
pred_df = predict_walkforward(test_df, x_cols, beta_for_pred, label_col)

print(f"预测结果: {len(pred_df):,} 行")
if len(pred_df) > 0:
    pred_df = pred_df.replace([np.inf, -np.inf], np.nan)
    print(f"  y_pred 范围: [{pred_df['y_pred'].min():.6f}, {pred_df['y_pred'].max():.6f}]")
    print(f"  y_pred 均值: {pred_df['y_pred'].mean():.6f}")
    print(f"  y_pred 标准差: {pred_df['y_pred'].std():.6f}")
    print(f"  y_pred NaN 数: {pred_df['y_pred'].isna().sum():,}")
print(f"[OK] Step 8 完成")
# Out:
# 预测结果: 14,120 行
#   y_pred 范围: [-0.078172, 0.103439]
#   y_pred 均值: 0.009644
#   y_pred 标准差: 0.019488
#   y_pred NaN 数: 0
# [OK] Step 8 完成

# %% [markdown]
# ## Step 9 — IC 评估（与 baseline 完全相同）
#
# 日度 Spearman IC + 汇总指标，与 baseline 结果对比。

# %%
if len(pred_df) > 0:
    ic_series, ic_summary_dict = evaluate_ic(pred_df)

    print(f"=== IC 汇总 [{MODEL_TYPE.upper()}, alpha={ALPHA}] ===")
    for k, v in ic_summary_dict.items():
        print(f"  {k}: {v:.6f}" if isinstance(v, float) else f"  {k}: {v}")

    print(f"\n=== 与 Baseline (OLS) 对比 ===")
    baseline_ref = {"ic_mean": 0.1357, "ic_ir": 5.66, "pos_ratio": 0.8796}
    for k, bv in baseline_ref.items():
        mv = ic_summary_dict.get(k, float('nan'))
        diff = mv - bv
        sign = "+" if diff >= 0 else ""
        print(f"  {k}: {MODEL_TYPE.upper()}={mv:.4f}  OLS={bv:.4f}  差异={sign}{diff:.4f}")

    # IC 序列图
    try:
        import matplotlib.pyplot as plt
        fig, ax = plt.subplots(figsize=(14, 4))
        ax.bar(range(len(ic_series)), ic_series.values,
               color=['#d62728' if v < 0 else '#2ca02c' for v in ic_series.values], alpha=0.7)
        ax.axhline(y=0, color='black', linewidth=0.5)
        ax.axhline(y=ic_series.mean(), color='#1f77b4', linestyle='--',
                   label=f"Mean IC={ic_series.mean():.4f}")
        ax.axhline(y=0.1357, color='gray', linestyle=':', alpha=0.6,
                   label="Baseline OLS Mean IC=0.1357")
        ax.set_title(f"Fold {FOLD_ID} — Daily Spearman IC ({MODEL_TYPE.upper()}, alpha={ALPHA})")
        ax.set_xlabel("Test day index")
        ax.set_ylabel("Spearman IC")
        ax.legend()
        plt.tight_layout()
        plt.show()
    except Exception as e:
        print(f"  [图表跳过] {e}")
else:
    print("[ERROR] 无预测结果，跳过 IC 评估")
    ic_series = pd.Series(dtype=float)
    ic_summary_dict = {}
# Out:
# === IC 汇总 [LASSO, alpha=0.0001] ===
#   ic_mean: 0.136406
#   ic_std: 0.120691
#   ic_ir: 5.673593
#   pos_ratio: 0.879630
#   n_days: 108
#
# === 与 Baseline (OLS) 对比 ===
#   ic_mean: LASSO=0.1364  OLS=0.1357  差异=+0.0007
#   ic_ir: LASSO=5.6736  OLS=5.6600  差异=+0.0136
#   pos_ratio: LASSO=0.8796  OLS=0.8796  差异=+0.0000

# %% [markdown]
# ## Step 10 — 持久化输出
#
# 输出目录：`02_线性模型lasso_ridge/output/{date}/`，文件格式与 baseline 完全一致。
#
# summary.csv 额外记录 `model_type` 和 `alpha`，方便后续多次实验对比。

# %%
run_date = _dt.date.today().strftime("%Y%m%d")
out_dir = OUTPUT_DIR / run_date / f"{MODEL_TYPE}_tune_alpha{ALPHA}"
out_dir.mkdir(parents=True, exist_ok=True)
print(f"输出目录: {out_dir}")

if len(pred_df) > 0:
    pred_df_out = pred_df.replace([np.inf, -np.inf], np.nan).copy()

    # 1) y_pred
    pred_path = out_dir / f"fold_{FOLD_ID}_y_pred.parquet"
    pred_df_out.to_parquet(pred_path, index=False)
    print(f"[SAVED] {pred_path}  ({pred_df_out.shape[0]:,} rows)")

    # 2) IC series
    ic_path = out_dir / f"fold_{FOLD_ID}_ic_series.csv"
    ic_series.to_csv(ic_path, header=["ic"])
    print(f"[SAVED] {ic_path}")

    # 3) Summary
    summary_row = {
        "model_type": MODEL_TYPE,
        "alpha": ALPHA,
        "alpha_grid": str(ALPHA_GRID),
        "alpha_select_mode": f"train_last_{VAL_DAYS}_days_validation",
        "beta_update_mode": "baseline_aligned_shift1",
        "use_test_beta": True,
        "use_intercept": True,
        "ic_mean": ic_summary_dict.get("ic_mean", np.nan),
        "ic_std": ic_summary_dict.get("ic_std", np.nan),
        "ic_ir": ic_summary_dict.get("ic_ir", np.nan),
        "pos_ratio": ic_summary_dict.get("pos_ratio", np.nan),
        "n_days": ic_summary_dict.get("n_days", 0),
        "n_features_kept": len(kept_final),
        "note": "与原 OLS baseline 保持一致：train/test 均逐日拟合 beta，拼接后 EWM，再 shift(1) 预测；该口径用于模型横向比较，不是最严格样本外口径。"
    }
    summary_path = out_dir / f"fold_{FOLD_ID}_summary.csv"
    pd.DataFrame([summary_row]).to_csv(summary_path, index=False, encoding="utf-8-sig")
    print(f"[SAVED] {summary_path}")

    # 4) Kept factors
    factors_path = out_dir / f"fold_{FOLD_ID}_kept_factors.txt"
    factors_path.write_text("\n".join(kept_final), encoding="utf-8")
    print(f"[SAVED] {factors_path}  ({len(kept_final)} factors)")

    # 5) Beta history（平滑前，与 baseline 格式一致；包含截距列）
    beta_path = out_dir / f"fold_{FOLD_ID}_beta_history.parquet"
    beta_all.to_parquet(beta_path)
    print(f"[SAVED] {beta_path}  ({beta_all.shape[0]} days x {beta_all.shape[1]} cols)")

    # 6) 每日排序输出
    # 对 Lasso/Ridge 来说，reg_score = y_pred，即连续收益预测分数。
    rank_df = pred_df_out.dropna(subset=["trade_date", "ts_code", "y_pred"]).copy()

    if len(rank_df) > 0:
        rank_df["rank"] = (
            rank_df.groupby("trade_date")["y_pred"]
            .rank(ascending=False, method="first")
            .astype(int)
        )

        rank_df = (
            rank_df.sort_values(["trade_date", "rank"])
            [["trade_date", "rank", "ts_code", "y_pred"]]
            .rename(columns={"ts_code": "stockid", "y_pred": "reg_score"})
        )

        rank_path = out_dir / f"fold_{FOLD_ID}_rank_output.csv"
        rank_df.to_csv(rank_path, index=False, encoding="utf-8-sig")
        print(f"[SAVED] {rank_path}  ({rank_df.shape[0]:,} rows)")

    print(f"\n[DONE] Fold {FOLD_ID} [{MODEL_TYPE.upper()}, tuned alpha={ALPHA}] 全部输出完成 -> {out_dir}")
else:
    print("[ERROR] 无有效预测结果，跳过输出")
# Out:
# 输出目录: D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_y_pred.parquet  (14,120 rows)
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_ic_series.csv
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_summary.csv
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_kept_factors.txt  (38 factors)
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_beta_history.parquet  (1084 days x 39 cols)
# [SAVED] D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001\fold_1_rank_output.csv  (14,120 rows)
#
# [DONE] Fold 1 [LASSO, tuned alpha=0.0001] 全部输出完成 -> D:\个人\量化\ML_teamwork\01_线性模型\02_线性模型lasso_ridge\output\20260527\lasso_tune_alpha0.0001
